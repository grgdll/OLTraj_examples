# %%
# # this is to make the Jupyter notebook as wide as the screen (on the Mac at least)
# from IPython.core.display import display, HTML
# display(HTML("<style>.container { width:100% !important; }</style>"))
# %config InlineBackend.figure_format ='retina'

# %% [markdown]
# # OLTraj Example 1: Plot Lagrangian trajectories

# %% [markdown]
# ## Objective
# To extract and plot trajectories (bkw and fwd) for a given date.

# %% [markdown]
# ## Input data:
# Any OLTraj file, e.g., ```MERCATOR_025/2008/20081205_oltraj_025_uv_global.nc```

# %% [markdown]
# ## Code:

# %% [markdown]
# Import needed modules

# %%
import numpy as np
import xarray as xr
import os
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import glob

import matplotlib.ticker as mticker
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import cmocean as cm
from cartopy.util import add_cyclic_point

# %% [markdown]
# Read chl data

# %%
fn = '/data/datasets/CCI/v4.2-release/climatology/ESACCI-OC-MAPPED-CLIMATOLOGY-1M_MONTHLY_4km_PML_OCx_QAA-05-fv4.2.nc'
dschl = xr.open_dataset(fn)
dschl.assign_coords(lon=(dschl.lon + 180)) # convert longitude to 0-360 degs
chl2plot = dschl['chlor_a']

# %%
# read WOA data
fnwoa = "/fast_scratch/OPERA/Fig1/woa18_all_n00_01.nc"
ds_woa = xr.open_mfdataset(fnwoa, decode_times=False, combine='nested', concat_dim='time')
woa2plot = ds_woa['n_an'].sel(depth=0.0)

# %%
# # read rain data
# fn_rain = glob.glob("/fast_scratch/OPERA/Fig1/data/global-precipitation-climatology-project-gpcp-monthly/access/*/*nc")
# ds_gpcp = xr.open_mfdataset(fn_rain, combine='nested', concat_dim='time')
# ds_gpcp_mean = ds_gpcp['precip'].mean(dim="time", skipna=True)

# new_lon = np.linspace(ds_gpcp_mean.longitude[0], ds_gpcp_mean.longitude[-1], 144 * 4)
# new_latp = np.linspace(ds_gpcp_mean.latitude[0],ds_gpcp_mean.latitude[-1], 72 * 4)
# dsii = ds_gpcp_mean.interp(latitude=new_latp, longitude=new_lon)

# dataprec, lonprec = add_cyclic_point(dsii, coord=dsii['longitude'])
# dataprec, lonprec = add_cyclic_point(dataprec, coord=lonprec)
# dataprec, lonprec = add_cyclic_point(dataprec, coord=lonprec)
# dataprec, lonprec = add_cyclic_point(dataprec, coord=lonprec)

# %% [markdown]
# Read trajectories based on 1/12-deg model

# %%
# fn12 = '/data/datasets/Projects/OLTraj/Processed/Lagrangian_traj/MERCATOR_030/2008/20081205_oltraj_030_uv_global.nc'
fn12 = '/data/datasets/Projects/OLTraj/Processed/Lagrangian_traj/MERCATOR_030/2008/20080501_oltraj_030_uv_global.nc'
ds12 = xr.open_dataset(fn12)

# # convert longitude to 0-360 degs
# newlon = ds12['lon'].values
# ineg = np.argwhere(newlon < 0)
# newlon[ineg] = newlon[ineg] + 360.
# ds12.assign_coords(lon=(  newlon  ))



# # convert trajlon to 0-360 degs
# newtrajlon = ds12['trajlon'].values
# newtrajlon[newtrajlon<0] = newtrajlon[newtrajlon<0] +360.

# ds12['trajlon'].where(ds12.lon>-1000, newtrajlon) # this is to replace all values
# ds12

# %%
lonprec.shape#, new_lat, dataprec
dataprec.shape
# new_lat.shape
# Out:
# (288, 580)

# %% [markdown]
# Here `ds` contains `trajlon` and `trajlat` that are the variables containing the coordinates of the forward and backward trajectories for each grid point.
#
# To visualize the initial positions, let's plot trajlon and trajlat at time-index 29 (i.e., that corresponding to the date in the filename.

# %% [markdown]
# **Initialize figure projection add initial points and continents**

# %%
import matplotlib.colors as colors

# proj = ccrs.PlateCarree(central_longitude=180)
# proj = ccrs.Robinson(central_longitude = 200)

grid_skip = 20 # this is the stride for subsetting the data
it0 = 29 # this is the "time of the observation"

# globe
# da = ds

# # Argentinian basin and Drake's Passage
# da = ds.sel(lon=slice(-70, -15)).sel(lat=slice(-65, -25)) # subset geographic region of interest
# da12 = ds12.sel(lon=slice(-70, -15)).sel(lat=slice(-65, -25)) # subset geographic region of interest

# Equatorial Atlantic
# da = ds.sel(lon=slice(-70, 10)).sel(lat=slice(-25, 25)) # subset geographic region of interest

# # North Atlantic
# da = ds.sel(lon=slice(-90, 20)).sel(lat=slice(-90, 90)) # subset geographic region of interest
# da12 = ds12.sel(lon=slice(-90, 20)).sel(lat=slice(-90, 90)) # subset geographic region of interest

# woa2plotE = woa2plot.sel(lon=slice(100, 180)).sel(lat=slice(-90, 90))
# woa2plotW = woa2plot.sel(lon=slice(-180, -75)).sel(lat=slice(-90, 90))

# new_lon = np.linspace(woa2plot.lon[0], woa2plot.lon[-1], 144 * 2)
# new_lat = np.linspace(woa2plot.lat[0], woa2plot.lat[-1], 72 *2)
# woa2ploti = woa2plot.interp(lat=new_lat, lon=new_lon)
# data, lon = add_cyclic_point(woa2ploti, coord=woa2ploti['lon'])
# data, lon = add_cyclic_point(woa2ploti, coord=woa2ploti['lon'])




chl2plotE = chl2plot.sel(lon=slice(100, 180)).sel(lat=slice(-90, 90))
chl2plotW = chl2plot.sel(lon=slice(-180, -75)).sel(lat=slice(-90, 90))

new_lon = np.linspace(chl2plot.lon[0], chl2plot.lon[-1], 144 * 2)
new_lat = np.linspace(chl2plot.lat[0], chl2plot.lat[-1], 72 *2)
chl2ploti = chl2plot.interp(lat=new_lat, lon=new_lon)
data, lon = add_cyclic_point(chl2ploti, coord=chl2ploti['lon'])
data, lon = add_cyclic_point(chl2ploti, coord=chl2ploti['lon'])


# North Pacific
# da = ds.sel(lon=slice(100, 260)).sel(lat=slice(-90, 90)) # subset geographic region of interest
da12 = ds12.sel(lon=slice(100, 180)).sel(lat=slice(-90, 90)) # subset geographic region of interest
da12b = ds12.sel(lon=slice(-180, -75)).sel(lat=slice(-90, 90)) # subset geographic region of interest


# da_bkw = da.sel(time=slice( da.time[0], da.time[it0]  )) # subset backward trajectories
# da_fwd = da.sel(time=slice( da.time[it0], da.time[-1]  )) # subset forward trajectories

da12_bkw = da12.sel(time=slice( da12.time[0], da12.time[it0]  )) # subset backward trajectories
da12_fwd = da12.sel(time=slice( da12.time[it0], da12.time[-1]  )) # subset forward trajectories

da12b_bkw = da12b.sel(time=slice( da12b.time[0], da12b.time[it0]  )) # subset backward trajectories
da12b_fwd = da12b.sel(time=slice( da12b.time[it0], da12b.time[-1]  )) # subset forward trajectories




fig = plt.figure(figsize=(30,80))
ax = fig.add_subplot(111, projection=ccrs.PlateCarree(central_longitude=180) )

# WOA = ax.pcolormesh(  lon, woa2ploti['lat'], data[0], transform=ccrs.PlateCarree(), \
#                 linewidths=4, vmin=0, vmax=30, cmap = cm.cm.thermal )
# # add colorscale
# cbaxes = fig.add_axes([0.7, 0.58, 0.15, 0.01]) 
# cb = plt.colorbar(WOA, cax = cbaxes, orientation="horizontal", pad=0.03)  
# params = {'mathtext.default': 'regular' }          
# plt.rcParams.update(params)
# cb.set_label("$NO_3$ [$\mu$mol/kg]", fontsize=40, color='k')
# cb.ax.tick_params(labelsize=30)

CHL = ax.pcolormesh(  lon, chl2ploti['lat'], data[0], transform=ccrs.PlateCarree(), \
                linewidths=4, norm=colors.LogNorm(vmin=0.01, vmax=2), cmap =plt.get_cmap('ocean_r')) # cm.cm.ocean_r )
# add colorscale
cbaxes = fig.add_axes([0.7, 0.52, 0.15, 0.01]) 
cb = plt.colorbar(CHL, cax = cbaxes, orientation="horizontal", pad=0.03, ticks=[0.02, 0.2, 2])  
params = {'mathtext.default': 'regular' }          
plt.rcParams.update(params)
cb.set_label("$chl$ [mg m$^{-3}$]", fontsize=40, color='k')
cb.ax.set_xticklabels(['0.02', '0.2', '2'])  # horizontal colorbar
cb.ax.tick_params(labelsize=30)


# # plot rain
# CS = ax.contour(  lonprec, new_latp, dataprec, transform=ccrs.PlateCarree(), \
#                 linewidths=4, colors='w' )
# ax.clabel(CS, inline=True, fontsize=30, fmt='%.0f')



# for ilon in range(0, len(da_bkw.lon), grid_skip):
#     for ilat in range(0, len(da_bkw.lat), grid_skip):
#         # bwk trajs in black
#         ax.plot(da_bkw['trajlon'][:,ilat,ilon], da_bkw['trajlat'][:,ilat,ilon], 5 , color='k', linestyle='-', transform=ccrs.PlateCarree() )
#         # fwd trajs in blue
#         ax.plot(da_fwd['trajlon'][:,ilat,ilon], da_fwd['trajlat'][:,ilat,ilon], 5 , color='b', linestyle='-', transform=ccrs.PlateCarree() )
# ax.scatter(da['trajlon'][it0, ::grid_skip, ::grid_skip], da['trajlat'][it0, ::grid_skip, ::grid_skip], 40 ,'r', marker='o', transform=ccrs.PlateCarree(), zorder=60 )



for ilon in range(0, len(da12_bkw.lon), grid_skip):
    for ilat in range(0, len(da12_bkw.lat), grid_skip):
        # bwk trajs in black
#         ax.plot(da12_bkw['trajlon'][:,ilat,ilon], da12_bkw['trajlat'][:,ilat,ilon], 5 , color='b', linestyle='-', transform=ccrs.PlateCarree() )
        # fwd trajs in blue
        ax.scatter(da12_fwd['trajlon'][:,ilat,ilon], da12_fwd['trajlat'][:,ilat,ilon], 5 , color='w', marker='.', transform=ccrs.PlateCarree() )
ax.scatter(da12['trajlon'][-1, ::grid_skip, ::grid_skip], da12['trajlat'][-1, ::grid_skip, ::grid_skip], 100 ,'w', marker='o',  transform=ccrs.PlateCarree(), zorder=60 )

for ilon in range(0, len(da12b_bkw.lon), grid_skip):
    for ilat in range(0, len(da12b_bkw.lat), grid_skip):
        # bwk trajs in black
#         ax.plot(da12_bkw['trajlon'][:,ilat,ilon], da12_bkw['trajlat'][:,ilat,ilon], 5 , color='b', linestyle='-', transform=ccrs.PlateCarree() )
        # fwd trajs in blue
        ax.scatter(da12b_fwd['trajlon'][:,ilat,ilon], da12b_fwd['trajlat'][:,ilat,ilon], 5 , color='w', marker='.', transform=ccrs.PlateCarree() )
ax.scatter(da12b['trajlon'][-1, ::grid_skip, ::grid_skip], da12b['trajlat'][-1, ::grid_skip, ::grid_skip], 100 ,'w', marker='o',  transform=ccrs.PlateCarree(), zorder=60 )



ax.add_feature(cfeature.NaturalEarthFeature('physical', 'land', '50m', edgecolor='k', facecolor='darkgray'))
ax.set_extent([120, 285, 0, 70], ccrs.PlateCarree())
# ax.set_extent([-70, 10, -25, 25], ccrs.PlateCarree())
# ax.set_extent([-70, 10, 25, 65], ccrs.PlateCarree())
# ax.gridlines(draw_labels=True)




# # add deployment sites
# OSP = (215, 50)
# SOTS = (142, -47)
# K2 = (160, 47)
# S1 = (145, 30)
# EqPac = (250, -5)

# k = 200

# # ax.scatter(K2[0], K2[1], 60*k ,'w', marker='o',  transform=ccrs.PlateCarree(), zorder=60 )
# ax.text(K2[0], K2[1], "1", transform=ccrs.PlateCarree(),
#          bbox={"boxstyle" : "circle", "facecolor":"w", "edgecolor":"r", "linewidth":8}, zorder=60, size=60 )

# # ax.scatter(OSP[0], OSP[1], 60*k ,'w', marker='o', edgecolors='r', linewidths=10, transform=ccrs.PlateCarree(), zorder=60 )
# ax.text(OSP[0], OSP[1], "2", transform=ccrs.PlateCarree(),
#          bbox={"boxstyle" : "circle", "facecolor":"w", "edgecolor":"r", "linewidth":8}, zorder=60, size=60 )

# # ax.scatter(EqPac[0], EqPac[1], 60*k ,'w', marker='o',  transform=ccrs.PlateCarree(), zorder=60 )
# ax.text(EqPac[0], EqPac[1], "3", transform=ccrs.PlateCarree(),
#          bbox={"boxstyle" : "circle", "facecolor":"w", "edgecolor":"r", "linewidth":8}, zorder=60, size=60 )

# # ax.scatter(SOTS[0], SOTS[1], 60*k, 'w', marker='o',  transform=ccrs.PlateCarree(), zorder=60 )
# ax.text(SOTS[0], SOTS[1], "4", transform=ccrs.PlateCarree(),
#          bbox={"boxstyle" : "circle", "facecolor":"w", "edgecolor":"r", "linewidth":8}, zorder=60, size=60 )

# # ax.scatter(S1[0], S1[1], 60*k ,'w', marker='o',  transform=ccrs.PlateCarree(), zorder=60 )
# ax.text(S1[0], S1[1], "5", transform=ccrs.PlateCarree(),
#          bbox={"boxstyle" : "circle", "facecolor":"w", "edgecolor":"r", "linewidth":8}, zorder=60, size=60 )




gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=0, color='gray', alpha=0.5, linestyle='--')
gl.xlabels_top = False
gl.xlabels_bottom = True
gl.ylabels_left = True
gl.ylabels_right = False
gl.xlines = True
gl.xlocator = mticker.FixedLocator([-80, -105, -130, -155, 180, 155, 130])
# gl.ylocator = mticker.FixedLocator([-60, -40, -20, 0, 20, 40, 60])
gl.ylocator = mticker.FixedLocator([0, 20, 40, 60])
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER
gl.ylabel_style = {'fontsize': 60, 'color': 'k'}
gl.xlabel_style = {'fontsize': 60, 'color': 'k'}
# Out:
# /users/modellers/gdal/miniconda3/envs/AMT29/lib/python3.7/site-packages/matplotlib/colors.py:1110: RuntimeWarning: invalid value encountered in less_equal
#   mask |= resdat <= 0

# %%
# Out:
# (1, 288, 577)

# %%
ds12['lon'].values
# Out:
# array([-180.  , -179.75, -179.5 , ...,  179.25,  179.5 ,  179.75])

# %%
da12b_bkw['trajlon'].values
# Out:
# array([[[-175.80803 , -176.09998 , -175.7915  , ...,         nan,
#                  nan,         nan],
#         [-179.38304 , -175.62625 , -176.17159 , ...,         nan,
#                  nan,         nan],
#         [ 178.62585 ,  175.97626 ,  178.38898 , ...,         nan,
#                  nan,         nan],
#         ...,
#         [ 140.63368 ,  140.82097 ,  141.01927 , ...,  -88.70201 ,
#           -76.24177 ,  -68.08367 ],
#         [ 127.40223 ,  127.545456,  127.66113 , ...,  103.86438 ,
#           102.470726,  100.38851 ],
#         [ 112.23731 ,  112.259346,  112.31443 , ...,  -56.00902 ,
#           -54.962402,  -54.147144]],
#
#        [[-175.90718 , -176.18811 , -175.89616 , ...,         nan,
#                  nan,         nan],
#         [-179.27838 , -175.7254  , -176.29277 , ...,         nan,
#                  nan,         nan],
#         [ 178.78009 ,  175.97626 ,  178.4716  , ...,         nan,
#                  nan,         nan],
#         ...,
#         [ 141.60316 ,  141.79597 ,  141.99979 , ...,  -92.59653 ,
#           -77.16169 ,  -69.41122 ],
#         [ 128.69675 ,  128.83997 ,  128.96115 , ...,  104.69066 ,
#           103.24192 ,  101.060555],
#         [ 113.22884 ,  113.256386,  113.32249 , ...,  -56.01453 ,
#           -54.96791 ,  -54.152653]],
#
#        [[-175.9898  , -176.23769 , -175.97879 , ...,         nan,
#                  nan,         nan],
#         [-179.14067 , -175.79701 , -176.36989 , ...,         nan,
#                  nan,         nan],
#         [ 178.95085 ,  176.0038  ,  178.56526 , ...,         nan,
#                  nan,         nan],
#         ...,
#         [ 142.31377 ,  142.52309 ,  142.73242 , ...,  -93.10331 ,
#           -78.142204,  -70.74428 ],
#         [ 129.61115 ,  129.75989 ,  129.87556 , ...,  104.61354 ,
#           103.02158 ,  101.20377 ],
#         [ 113.99453 ,  114.02758 ,  114.09368 , ...,  -56.02004 ,
#           -54.96791 ,  -54.15816 ]],
#
#        ...,
#
#        [[ 179.98094 , -179.75763 , -179.49321 , ...,         nan,
#                  nan,         nan],
#         [-179.73009 , -178.89279 , -178.52373 , ...,         nan,
#                  nan,         nan],
#         [ 179.6229  ,  179.98645 , -179.56483 , ...,         nan,
#                  nan,         nan],
#         ...,
#         [ 177.39194 ,  177.63983 ,  177.8822  , ...,  -74.05489 ,
#           -73.8015  ,  -73.54811 ],
#         [ 175.48048 ,  175.72287 ,  175.96524 , ...,  -74.66083 ,
#           -74.37989 ,  -74.082436],
#         [ 171.18385 ,  171.43173 ,  171.67412 , ...,  -74.985825,
#           -74.72693 ,  -74.44599 ]],
#
#        [[-179.98898 , -179.77415 , -179.55933 , ...,         nan,
#                  nan,         nan],
#         [-179.84576 , -179.38304 , -179.025   , ...,         nan,
#                  nan,         nan],
#         [ 179.86526 , -179.85678 , -179.53178 , ...,         nan,
#                  nan,         nan],
#         ...,
#         [ 178.61484 ,  178.86272 ,  179.10509 , ...,  -74.881165,
#           -74.62778 ,  -74.37989 ],
#         [ 177.5517  ,  177.79958 ,  178.04745 , ...,  -75.151085,
#           -74.875656,  -74.61125 ],
#         [ 175.2987  ,  175.5466  ,  175.79448 , ...,  -75.911255,
#           -75.663376,  -75.40447 ]],
#
#        [[-180.      , -179.75212 , -179.49872 , ...,         nan,
#                  nan,         nan],
#         [-180.      , -179.75212 , -179.49872 , ...,         nan,
#                  nan,         nan],
#         [-180.      , -179.75212 , -179.49872 , ...,         nan,
#                  nan,         nan],
#         ...,
#         [-180.      , -179.75212 , -179.49872 , ...,  -75.498116,
#           -75.25024 ,  -75.00235 ],
#         [-180.      , -179.75212 , -179.49872 , ...,  -75.498116,
#           -75.25024 ,  -75.00235 ],
#         [-180.      , -179.75212 , -179.49872 , ...,  -75.498116,
#           -75.25024 ,  -75.00235 ]]], dtype=float32)

# %%
ls -l /fast_scratch/AtlantOS
# Out:
# total 2673744
# -rw-r-xr-x. 1 gdal pmlersem 31531857 Oct 15  2019 3901497_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 34451363 Jan 24  2020 3901498_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 10611252 Feb 11  2020 4901802_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  9693017 Feb 11  2020 4901803_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  1258908 Feb 11  2020 4901804_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 10387762 Feb 11  2020 4901805_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem   805253 Feb 11  2020 4901806_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  2700569 Feb 11  2020 6900796_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem   364282 Feb 11  2020 6900797_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  6729373 Feb 11  2020 6900798_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  3413684 Feb 11  2020 6900799_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 31445577 Feb 11  2020 6900807_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem   650958 Feb 11  2020 6900876_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem   563956 Feb 11  2020 6900877_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 35752585 Feb 11  2020 6901004_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  2187340 Feb 11  2020 6901032_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 36492155 Feb  3  2020 6901180_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 36262589 Feb  2  2020 6901181_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 70440650 Feb 11  2020 6901480_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  3643790 Feb 11  2020 6901481_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  7300581 Feb 11  2020 6901482_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  5250891 Feb 11  2020 6901483_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  5493346 Feb 11  2020 6901484_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 15256441 Feb 11  2020 6901485_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 77210159 Feb 11  2020 6901486_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  7524159 Feb 11  2020 6901489_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  1182327 Feb 11  2020 6901490_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 13420310 Feb 11  2020 6901491_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 57209296 Feb 11  2020 6901492_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 18193175 Feb 11  2020 6901493_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 22947953 Feb 11  2020 6901494_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 13961554 Feb 11  2020 6901496_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 15020540 Feb 11  2020 6901510_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 18924344 Feb 11  2020 6901511_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 11972656 Feb 11  2020 6901512_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 17575154 Feb 11  2020 6901513_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  3504657 Feb 11  2020 6901514_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  6581887 Feb 11  2020 6901515_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 75765369 Feb 11  2020 6901516_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  7046846 Feb 11  2020 6901517_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  6701738 Feb 11  2020 6901518_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 13235799 Feb 11  2020 6901519_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  4550990 Feb 11  2020 6901520_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  6064693 Feb 11  2020 6901521_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem   690415 Feb 11  2020 6901522_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 33586878 Feb 11  2020 6901523_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 66175274 Feb 11  2020 6901524_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 69355523 Feb 11  2020 6901525_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  1378088 Feb 11  2020 6901526_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 69844435 Feb 11  2020 6901527_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  9748494 Feb 11  2020 6901529_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 12678262 Feb 11  2020 6901574_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 25876270 Feb 11  2020 6901575_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 47335115 Feb 11  2020 6901576_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 29493600 Feb 11  2020 6901578_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 14625057 Feb 11  2020 6901579_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 14147953 Feb 11  2020 6901580_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 32948445 Feb 11  2020 6901581_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 34432494 Feb 11  2020 6901582_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 30992930 Feb 11  2020 6901583_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 32929311 Feb 11  2020 6901584_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 20937802 Feb 11  2020 6901585_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  7534131 Feb 11  2020 6901600_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  3963116 Feb 11  2020 6901605_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 57237902 Feb 11  2020 6901646_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 68888259 Feb 11  2020 6901647_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 16952460 Feb 11  2020 6901648_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 14815071 Feb 11  2020 6901649_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  9120204 Feb 11  2020 6901650_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem   889396 Feb 11  2020 6901651_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 13721756 Feb 11  2020 6901653_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 33422873 Feb 11  2020 6901654_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  7530161 Feb 11  2020 6901657_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 28378356 Feb 11  2020 6901688_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  6760667 Feb 11  2020 6901689_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 16054943 Feb 11  2020 6901765_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 48351472 Feb 11  2020 6901767_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 18101513 Feb 11  2020 6901768_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 14994291 Feb 11  2020 6901769_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 15845541 Feb 11  2020 6901770_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 12994720 Feb 11  2020 6901771_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 10334848 Feb 11  2020 6901772_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  7623977 Feb 11  2020 6901774_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 10631265 Feb 11  2020 6901775_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 22331735 Feb 11  2020 6901776_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  6872361 Feb 11  2020 6901860_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  4409529 Feb 11  2020 6901861_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 22480854 Feb 11  2020 6901862_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  9708845 Feb 11  2020 6901863_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 19597981 Feb 11  2020 6901864_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 23763951 Feb 11  2020 6901865_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 41145103 Feb 11  2020 6901866_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem   609417 Feb 11  2020 6902014_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem   424327 Feb 11  2020 6902018_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem   576131 Feb 11  2020 6902019_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem   652249 Feb 11  2020 6902020_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem   403644 Feb 11  2020 6902021_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem   636481 Feb 11  2020 6902024_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem   860117 Feb 11  2020 6902027_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem   468389 Feb 11  2020 6902028_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  6755671 Feb 11  2020 6902544_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  7324165 Feb 11  2020 6902545_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem   575389 Feb 11  2020 6902546_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 89041796 Feb 11  2020 6902547_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  7749996 Feb 11  2020 6902548_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  7662221 Feb 11  2020 6902549_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  7579564 Feb 11  2020 6902550_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  6588243 Feb 11  2020 6902666_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 10550659 Feb 11  2020 6902667_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  9636085 Feb 11  2020 6902668_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  9279899 Feb 11  2020 6902669_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  9385935 Feb 11  2020 6902670_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 13311193 Feb 11  2020 6902671_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  5255092 Feb 11  2020 6902700_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 14221146 Feb 11  2020 6902732_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  7240362 Feb 11  2020 6902733_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 31766862 Feb 11  2020 6902734_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 33651844 Feb 11  2020 6902735_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 36504118 Feb 11  2020 6902736_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 35051908 Feb 11  2020 6902737_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  8256391 Feb 11  2020 6902738_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 37817970 Feb 11  2020 6902739_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 14454528 Feb 11  2020 6902742_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 11020766 Feb 11  2020 6902743_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  6141947 Feb 11  2020 6902826_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 74810127 Feb 11  2020 6902828_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  9399359 Feb 11  2020 6902829_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 11922015 Feb 11  2020 6902879_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  7939825 Feb 11  2020 6902880_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 11262620 Feb 11  2020 6902896_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 15867878 Feb 11  2020 6902897_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  1631607 Feb 11  2020 6902899_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  6028271 Feb 11  2020 6902900_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  5660872 Feb 11  2020 6902901_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  7146511 Feb 11  2020 6902902_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 12105958 Feb 11  2020 6902903_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 11910464 Feb 11  2020 6902904_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  7797880 Feb 11  2020 6902905_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  2807270 Feb 11  2020 6902953_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  8925253 Feb 11  2020 6902954_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  6595773 Feb 11  2020 6902967_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  2117434 Feb 11  2020 6902968_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  9011787 Feb 11  2020 6902969_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  3049164 Feb 11  2020 6903026_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  8429677 Feb 11  2020 6903197_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  4294871 Feb 11  2020 6903235_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 24401234 Feb 11  2020 6903240_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 16877534 Feb 11  2020 6903247_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 27934522 Feb 11  2020 6903249_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 29355429 Feb 11  2020 6903250_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  5652067 Feb 11  2020 6903273_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  4169692 Feb 11  2020 6903549_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  4080936 Feb 11  2020 6903550_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  3873122 Feb 11  2020 6903551_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  5540250 Feb 11  2020 6903553_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  6321426 Feb 11  2020 6903554_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  5863777 Feb 11  2020 6903555_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem   646568 Feb 11  2020 6903697_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem  2020831 Feb 11  2020 7900562_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 43649762 Feb 11  2020 7900591_Sprof.nc*
# -rw-r-xr-x. 1 gdal pmlersem 14119094 Feb 11  2020 7900592_Sprof.nc*
